# %%
# Import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from sqlalchemy import create_engine
from sqlalchemy.engine.url import URL
import config
from config import CONNSTRING
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler

# %%
# Load the data from SQL and create a DataFrame
engine= create_engine(CONNSTRING)

query = "SELECT * FROM customer_data"
df = pd.read_sql(query, engine)

# Display the DataFrame
df.head()
# Out:
#    Customer ID  age gender Item Purchased  category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                   53.0
# 1            2   19   Male        Sweater  Clothing                   64.0
# 2            3   50   Male          Jeans  Clothing                   73.0
# 3            4   21   Male        Sandals  Footwear                   90.0
# 4            5   45   Male         Blouse  Clothing                   49.0
#
#         location size      color  season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
#    Shipping Type Discount Applied Promo Code Used  Previous Purchases  \
# 0        Express              Yes             Yes                  14
# 1        Express              Yes             Yes                   2
# 2  Free Shipping              Yes             Yes                  23
# 3   Next Day Air              Yes             Yes                  49
# 4  Free Shipping              Yes             Yes                  31
#
#   Payment Method Frequency of Purchases
# 0          Venmo            Fortnightly
# 1           Cash            Fortnightly
# 2    Credit Card                 Weekly
# 3         PayPal                 Weekly
# 4         PayPal               Annually

# %%
# Dispay column names
df.columns
# Out:
# Index(['Customer ID', 'age', 'gender', 'Item Purchased', 'category',
#        'Purchase Amount (USD)', 'location', 'size', 'color', 'season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases'],
#       dtype='object')

# %%
# Display data amount
df.shape[0]
# Out:
# 3900

# %%
# Handle Missing Values: 
df.isna().sum()
# Out:
# Customer ID               0
# age                       0
# gender                    0
# Item Purchased            0
# category                  0
# Purchase Amount (USD)     0
# location                  0
# size                      0
# color                     0
# season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
# Display the data types for each column
print(df.dtypes)
# Out:
# Customer ID                 int64
# age                         int64
# gender                     object
# Item Purchased             object
# category                   object
# Purchase Amount (USD)     float64
# location                   object
# size                       object
# color                      object
# season                     object
# Review Rating             float64
# Subscription Status        object
# Shipping Type              object
# Discount Applied           object
# Promo Code Used            object
# Previous Purchases          int64
# Payment Method             object
# Frequency of Purchases     object
# dtype: object

# %%
# Converting columns to appropriate data types
df['Customer ID'] = df['Customer ID'].astype(int)  # Assuming 'Customer ID' is an integer
df['age'] = df['age'].astype(int)  # Age is an integer
df['gender'] = df['gender'].astype('category')  # Gender as category
df['Item Purchased'] = df['Item Purchased'].astype('category')  # Item Purchased as category
df['category'] = df['category'].astype('category')  # Category as category
df['Purchase Amount (USD)'] = df['Purchase Amount (USD)'].astype(float)  # Purchase Amount as float
df['location'] = df['location'].astype('category')  # Location as category
df['size'] = df['size'].astype('category')  # Size as category
df['color'] = df['color'].astype('category')  # Color as category
df['season'] = df['season'].astype('category')  # Season as category
df['Review Rating'] = df['Review Rating'].astype(float)  # Review Rating as float
df['Subscription Status'] = df['Subscription Status'].astype('category')  # Subscription Status as category
df['Shipping Type'] = df['Shipping Type'].astype('category')  # Shipping Type as category
df['Discount Applied'] = df['Discount Applied'].astype('category')  # Discount Applied as category (assuming 'Yes'/'No')
df['Promo Code Used'] = df['Promo Code Used'].astype('category')  # Promo Code Used as category
df['Previous Purchases'] = df['Previous Purchases'].astype(int)  # Previous Purchases as integer
df['Payment Method'] = df['Payment Method'].astype('category')  # Payment Method as category
df['Frequency of Purchases'] = df['Frequency of Purchases'].astype('category')  # Frequency of Purchases as category

# %% [markdown]
# Based on certain customer characteristics, we want to build a model that can predict the categories that the customers will buy, so we can use it for designing a marketing campaign that sends them specific promo codes and advertising related to that product category.
#
# We'll try to use a neural network model to predict the categories that the customers will buy (using 4 targets), based on the following features: age, gender, item purchased, purchased amount in USD and location.

# %%
# Create a dataframe with the columns that we'll use to predict the categories
customer_df = df[['age', 'gender','Item Purchased', 'category', 'Purchase Amount (USD)', 'location']].copy()
customer_df.head()
# Out:
#    age gender Item Purchased  category  Purchase Amount (USD)       location
# 0   55   Male         Blouse  Clothing                   53.0       Kentucky
# 1   19   Male        Sweater  Clothing                   64.0          Maine
# 2   50   Male          Jeans  Clothing                   73.0  Massachusetts
# 3   21   Male        Sandals  Footwear                   90.0   Rhode Island
# 4   45   Male         Blouse  Clothing                   49.0         Oregon

# %%
# Convert the categorical data in dummies and create a dataframe with that information
customer_df_encoded = pd.get_dummies(customer_df)
customer_df_encoded.head()
# Out:
#    age  Purchase Amount (USD)  gender_Female  gender_Male  \
# 0   55                   53.0          False         True
# 1   19                   64.0          False         True
# 2   50                   73.0          False         True
# 3   21                   90.0          False         True
# 4   45                   49.0          False         True
#
#    Item Purchased_Backpack  Item Purchased_Belt  Item Purchased_Blouse  \
# 0                    False                False                   True
# 1                    False                False                  False
# 2                    False                False                  False
# 3                    False                False                  False
# 4                    False                False                   True
#
#    Item Purchased_Boots  Item Purchased_Coat  Item Purchased_Dress  ...  \
# 0                 False                False                 False  ...
# 1                 False                False                 False  ...
# 2                 False                False                 False  ...
# 3                 False                False                 False  ...
# 4                 False                False                 False  ...
#
#    location_South Dakota  location_Tennessee  location_Texas  location_Utah  \
# 0                  False               False           False          False
# 1                  False               False           False          False
# 2                  False               False           False          False
# 3                  False               False           False          False
# 4                  False               False           False          False
#
#    location_Vermont  location_Virginia  location_Washington  \
# 0             False              False                False
# 1             False              False                False
# 2             False              False                False
# 3             False              False                False
# 4             False              False                False
#
#    location_West Virginia  location_Wisconsin  location_Wyoming
# 0                   False               False             False
# 1                   False               False             False
# 2                   False               False             False
# 3                   False               False             False
# 4                   False               False             False
#
# [5 rows x 83 columns]

# %%
# Display the columns of the dataframe
customer_df_encoded.columns
# Out:
# Index(['age', 'Purchase Amount (USD)', 'gender_Female', 'gender_Male',
#        'Item Purchased_Backpack', 'Item Purchased_Belt',
#        'Item Purchased_Blouse', 'Item Purchased_Boots', 'Item Purchased_Coat',
#        'Item Purchased_Dress', 'Item Purchased_Gloves',
#        'Item Purchased_Handbag', 'Item Purchased_Hat', 'Item Purchased_Hoodie',
#        'Item Purchased_Jacket', 'Item Purchased_Jeans',
#        'Item Purchased_Jewelry', 'Item Purchased_Pants',
#        'Item Purchased_Sandals', 'Item Purchased_Scarf',
#        'Item Purchased_Shirt', 'Item Purchased_Shoes', 'Item Purchased_Shorts',
#        'Item Purchased_Skirt', 'Item Purchased_Sneakers',
#        'Item Purchased_Socks', 'Item Purchased_Sunglasses',
#        'Item Purchased_Sweater', 'Item Purchased_T-shirt',
#        'category_Accessories', 'category_Clothing', 'category_Footwear',
#        'category_Outerwear', 'location_Alabama', 'location_Alaska',
#        'location_Arizona', 'location_Arkansas', 'location_California',
#        'location_Colorado', 'location_Connecticut', 'location_Delaware',
#        'location_Florida', 'location_Georgia', 'location_Hawaii',
#        'location_Idaho', 'location_Illinois', 'location_Indiana',
#        'location_Iowa', 'location_Kansas', 'location_Kentucky',
#        'location_Louisiana', 'location_Maine', 'location_Maryland',
#        'location_Massachusetts', 'location_Michigan', 'location_Minnesota',
#        'location_Mississippi', 'location_Missouri', 'location_Montana',
#        'location_Nebraska', 'location_Nevada', 'location_New Hampshire',
#        'location_New Jersey', 'location_New Mexico', 'location_New York',
#        'location_North Carolina', 'location_North Dakota', 'location_Ohio',
#        'location_Oklahoma', 'location_Oregon', 'location_Pennsylvania',
#        'location_Rhode Island', 'location_South Carolina',
#        'location_South Dakota', 'location_Tennessee', 'location_Texas',
#        'location_Utah', 'location_Vermont', 'location_Virginia',
#        'location_Washington', 'location_West Virginia', 'location_Wisconsin',
#        'location_Wyoming'],
#       dtype='object')

# %%
# Split our preprocessed data into our features and target arrays
#Features
X = customer_df_encoded.drop(columns=['category_Accessories','category_Footwear','category_Clothing','category_Outerwear'],axis=1).values

#Targets
y_accessories = customer_df_encoded['category_Accessories'].values
y_footwear = customer_df_encoded['category_Footwear'].values
y_clothing = customer_df_encoded['category_Clothing'].values
y_outerwear = customer_df_encoded['category_Outerwear'].values

# Number of classes for each target variable
num_classes_accessories = len(np.unique(y_accessories))
num_classes_footwear = len(np.unique(y_footwear))
num_classes_clothing = len(np.unique(y_clothing))
num_classes_outerwear = len(np.unique(y_outerwear))

# Convert targets to one-hot encoding
y_accessories = to_categorical(y_accessories, num_classes=num_classes_accessories).astype(np.float32)
y_footwear = to_categorical(y_footwear, num_classes=num_classes_footwear).astype(np.float32)
y_clothing = to_categorical(y_clothing, num_classes=num_classes_clothing).astype(np.float32)
y_outerwear = to_categorical(y_outerwear, num_classes=num_classes_outerwear).astype(np.float32)

# Split the data into training and testing sets
X_train, X_test, y_accessories_train, y_accessories_test = train_test_split(
    X, y_accessories, test_size=0.2, random_state=42
)

# Repeat the split for other targets, ensuring consistent splitting
y_footwear_train, y_footwear_test = train_test_split(
    y_footwear, test_size=0.2, random_state=42
)
y_clothing_train, y_clothing_test = train_test_split(
    y_clothing, test_size=0.2, random_state=42
)
y_outerwear_train, y_outerwear_test = train_test_split(
    y_outerwear, test_size=0.2, random_state=42
)

# Define the model
X_train = np.asarray(X_train).astype(np.float32)
X_test = np.asarray(X_test).astype(np.float32)
inputs = Input(shape=(X.shape[1],))

# Shared layers
x = Dense(64, activation='relu')(inputs)
x = Dense(32, activation='relu')(x)

# Output layers for each target
output_accessories = Dense(num_classes_accessories, activation='softmax', name='accessories')(x)
output_footwear = Dense(num_classes_footwear, activation='softmax', name='footwear')(x)
output_clothing = Dense(num_classes_clothing, activation='softmax', name='clothing')(x)
output_outerwear = Dense(num_classes_outerwear, activation='softmax', name='outerwear')(x)

# %%
# Define the model
X_train = np.asarray(X_train).astype(np.float32)
X_test = np.asarray(X_test).astype(np.float32)
inputs = Input(shape=(X.shape[1],))

# Shared layers
x = Dense(64, activation='relu')(inputs)
x = Dense(32, activation='relu')(x)

# Output layers for each target
output_accessories = Dense(num_classes_accessories, activation='softmax', name='accessories')(x)
output_footwear = Dense(num_classes_footwear, activation='softmax', name='footwear')(x)
output_clothing = Dense(num_classes_clothing, activation='softmax', name='clothing')(x)
output_outerwear = Dense(num_classes_outerwear, activation='softmax', name='outerwear')(x)

# Create and compile the model
model = Model(inputs=inputs, outputs=[output_accessories, output_footwear, output_clothing, output_outerwear])

model.compile(optimizer=Adam(),
              loss={'accessories': 'categorical_crossentropy',
                    'footwear': 'categorical_crossentropy',
                    'clothing': 'categorical_crossentropy',
                    'outerwear': 'categorical_crossentropy'},
              metrics={'accessories': 'accuracy',
                       'footwear': 'accuracy',
                       'clothing': 'accuracy',
                       'outerwear': 'accuracy'})

# Train the model
model.fit(X_train, {'accessories': y_accessories_train, 
                    'footwear': y_footwear_train, 
                    'clothing': y_clothing_train, 
                    'outerwear': y_outerwear_train},
          epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accessories_accuracy: 0.6151 - clothing_accuracy: 0.5431 - footwear_accuracy: 0.8450 - loss: 2.6377 - outerwear_accuracy: 0.9178
# Epoch 2/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7160 - clothing_accuracy: 0.7047 - footwear_accuracy: 0.8578 - loss: 1.8543 - outerwear_accuracy: 0.9078
# Epoch 3/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7918 - clothing_accuracy: 0.8373 - footwear_accuracy: 0.8531 - loss: 1.5800 - outerwear_accuracy: 0.9149
# Epoch 4/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.9178 - clothing_accuracy: 0.9357 - footwear_accuracy: 0.8844 - loss: 1.2308 - outerwear_accuracy: 0.9157
# Epoch 5/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.9754 - clothing_accuracy: 0.9648 - footwear_accuracy: 0.9387 - loss: 0.8453 - outerwear_accuracy: 0.9205
# Epoch 6/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 1.0000 - clothing_accuracy: 0.9900 - footwear_accuracy: 0.9955 - loss: 0.5199 - outerwear_accuracy: 0.9373
# Epoch 7/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 1.0000 - clothing_accuracy: 1.0000 - footwear_accuracy: 1.0000 - loss: 0.2937 - outerwear_accuracy: 0.9699
# Epoch 8/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accessories_accuracy: 1.0000 - clothing_accuracy: 1.0000 - footwear_accuracy: 1.0000 - loss: 0.1495 - outerwear_accuracy: 0.9974
# Epoch 9/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 1.0000 - clothing_accuracy: 1.0000 - footwear_accuracy: 1.0000 - loss: 0.0927 - outerwear_accuracy: 0.9996
# Epoch 10/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accessories_accuracy: 1.0000 - clothing_accuracy: 1.0000 - footwear_accuracy: 1.0000 - loss: 0.0587 - outerwear_accuracy: 1.0000

# %%
# Evaluate the model
results = model.evaluate(X_test, {'accessories': y_accessories_test, 
                                  'footwear': y_footwear_test, 
                                  'clothing': y_clothing_test, 
                                  'outerwear': y_outerwear_test})
# Print all results
for name, result in zip(model.metrics_names, results):
    print(f"{name}: {result}")
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 1.0000 - clothing_accuracy: 1.0000 - footwear_accuracy: 1.0000 - loss: 0.0428 - outerwear_accuracy: 1.0000
# loss: 0.04267256706953049
# compile_metrics: 1.0

# %% [markdown]
# After running the model with 10 epochs, we reached an accuracy of 100% for all the target variables. Although the accuracy is very high, after reviewing the results we found a bit strange that the model gave us this accuracy level. Therefore, we decided to dig deeper in the model characteristics. One of the possibilities for this high accuracy level could be that the model is overfitting. We also think that the reason why the model is overfitting is because there is not enough complexity in
# the training data, and the model converges too quickly, given that the 100% accuracy is reached after 6 epochs.
#
# Although the most straightforward way to fix overfitting is adding more training data, we were not able to do it because the company didn't provide us with more data fields or with an additional dataset. For this reason, we tried to fix this by keeping our training data the same and retraining the model using fewer epochs.

# %%
# Split our preprocessed data into our features and target arrays
#Features
X_2 = customer_df_encoded.drop(columns=['category_Accessories','category_Footwear','category_Clothing','category_Outerwear'],axis=1).values

#Targets
y_accessories_2 = customer_df_encoded['category_Accessories'].values
y_footwear_2 = customer_df_encoded['category_Footwear'].values
y_clothing_2 = customer_df_encoded['category_Clothing'].values
y_outerwear_2 = customer_df_encoded['category_Outerwear'].values

# Number of classes for each target variable
num_classes_accessories_2 = len(np.unique(y_accessories_2))
num_classes_footwear_2 = len(np.unique(y_footwear_2))
num_classes_clothing_2 = len(np.unique(y_clothing_2))
num_classes_outerwear_2 = len(np.unique(y_outerwear_2))

# Convert targets to one-hot encoding
y_accessories_2 = to_categorical(y_accessories_2, num_classes=num_classes_accessories_2).astype(np.float32)
y_footwear_2 = to_categorical(y_footwear_2, num_classes=num_classes_footwear_2).astype(np.float32)
y_clothing_2 = to_categorical(y_clothing_2, num_classes=num_classes_clothing_2).astype(np.float32)
y_outerwear_2 = to_categorical(y_outerwear_2, num_classes=num_classes_outerwear_2).astype(np.float32)

# Split the data into training and testing sets
X_train_2, X_test_2, y_accessories_train_2, y_accessories_test_2 = train_test_split(
    X, y_accessories_2, test_size=0.2, random_state=42
)

# Repeat the split for other targets, ensuring consistent splitting
y_footwear_train_2, y_footwear_test_2 = train_test_split(
    y_footwear_2, test_size=0.2, random_state=42
)
y_clothing_train_2, y_clothing_test_2 = train_test_split(
    y_clothing_2, test_size=0.2, random_state=42
)
y_outerwear_train_2, y_outerwear_test_2 = train_test_split(
    y_outerwear_2, test_size=0.2, random_state=42
)

# Define the model
X_train_2 = np.asarray(X_train_2).astype(np.float32)
X_test_2 = np.asarray(X_test_2).astype(np.float32)
inputs_2 = Input(shape=(X.shape[1],))

# Shared layers
x_2 = Dense(64, activation='relu')(inputs_2)
x_2 = Dense(32, activation='relu')(x_2)

# Output layers for each target
output_accessories_2 = Dense(num_classes_accessories_2, activation='softmax', name='accessories')(x_2)
output_footwear_2 = Dense(num_classes_footwear_2, activation='softmax', name='footwear')(x_2)
output_clothing_2 = Dense(num_classes_clothing_2, activation='softmax', name='clothing')(x_2)
output_outerwear_2 = Dense(num_classes_outerwear_2, activation='softmax', name='outerwear')(x_2)


# Create and compile the model
model_2 = Model(inputs=inputs_2, outputs=[output_accessories_2, output_footwear_2, output_clothing_2, output_outerwear_2])

model_2.compile(optimizer=Adam(),
              loss={'accessories': 'categorical_crossentropy',
                    'footwear': 'categorical_crossentropy',
                    'clothing': 'categorical_crossentropy',
                    'outerwear': 'categorical_crossentropy'},
              metrics={'accessories': 'accuracy',
                       'footwear': 'accuracy',
                       'clothing': 'accuracy',
                       'outerwear': 'accuracy'})


# Train the model
model_2.fit(X_train_2, {'accessories': y_accessories_train_2, 
                    'footwear': y_footwear_train_2, 
                    'clothing': y_clothing_train_2, 
                    'outerwear': y_outerwear_train_2},
          epochs=5, batch_size=32)
# Out:
# Epoch 1/5
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accessories_accuracy: 0.6039 - clothing_accuracy: 0.5256 - footwear_accuracy: 0.7160 - loss: 9.7999 - outerwear_accuracy: 0.5174
# Epoch 2/5
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7312 - clothing_accuracy: 0.7420 - footwear_accuracy: 0.8471 - loss: 1.8707 - outerwear_accuracy: 0.9207
# Epoch 3/5
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.8124 - clothing_accuracy: 0.9330 - footwear_accuracy: 0.8358 - loss: 1.5445 - outerwear_accuracy: 0.9175
# Epoch 4/5
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.9545 - clothing_accuracy: 0.9983 - footwear_accuracy: 0.8477 - loss: 1.1493 - outerwear_accuracy: 0.9157
# Epoch 5/5
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.9996 - clothing_accuracy: 1.0000 - footwear_accuracy: 0.8818 - loss: 0.7845 - outerwear_accuracy: 0.9140

# %%
# Evaluate the model
results_2 = model_2.evaluate(X_test_2, {'accessories': y_accessories_test_2, 
                                  'footwear': y_footwear_test_2, 
                                  'clothing': y_clothing_test_2, 
                                  'outerwear': y_outerwear_test_2})
# Print all results
for name, result in zip(model_2.metrics_names, results_2):
    print(f"{name}: {result}")
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accessories_accuracy: 0.9986 - clothing_accuracy: 1.0000 - footwear_accuracy: 0.9049 - loss: 0.5244 - outerwear_accuracy: 0.9339
# loss: 0.5442551970481873
# compile_metrics: 0.9987179636955261

# %% [markdown]
# The model with fewer epochs gave us a lower accuracy but still closer to 100% in most categories, which means that we can continue increasing the epochs to reach a higher accuracy. However, if we do so, we'll probably end up facing the overfitting issue that we saw in the previous attempt. For this reason, this could give us a hint that the neural network model may not be the best one to apply to this type of data.
#
# Since we don't have a lot of data and the features used to predict the targets are simple, maybe the Random Forest model would be a better for this problem.

# %%
# Convert non numeric data into numbers by using LabelEncoder
label_encoders = {}
for column in customer_df.columns:
    le = LabelEncoder()
    customer_df[column] = le.fit_transform(customer_df[column])
    label_encoders[column] = le

customer_df.head()
# Out:
#    age  gender  Item Purchased  category  Purchase Amount (USD)  location
# 0   37       1               2         1                     33        16
# 1    1       1              23         1                     44        18
# 2   32       1              11         1                     53        20
# 3    3       1              14         2                     70        38
# 4   27       1               2         1                     29        36

# %%
# Display number of unique values for each column
customer_df_unique_counts=customer_df.nunique()
print(customer_df_unique_counts)
# Out:
# age                      53
# gender                    2
# Item Purchased           25
# category                  4
# Purchase Amount (USD)    81
# location                 50
# dtype: int64

# %%
# Define target value and features
X = customer_df.drop('category', axis=1)
y = customer_df['category']

# %%
# Devide the data into training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Define the model
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Display model results
y_pred = model.predict(X_test)

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[366   4   0   0]
#  [  1 521   0   0]
#  [  1   1 187   0]
#  [  0   2   0  87]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       370
#            1       0.99      1.00      0.99       522
#            2       1.00      0.99      0.99       189
#            3       1.00      0.98      0.99        89
#
#     accuracy                           0.99      1170
#    macro avg       1.00      0.99      0.99      1170
# weighted avg       0.99      0.99      0.99      1170

# %% [markdown]
# After running the Random Forest model, we also observed that the accuracy is close to 100%. This makes us conclude that we don't have the necessary amount of data to train a machine learning model. However, we prefer to do it with a Random Forest because of the simplicity of the data.

# %% [markdown]
# Another conclusion could be that the accuracy on predicting the category that the customer will buy could come from the fact that we also have the information about the item purchased, which is directly related to the item category. We want to check if the accuracy changes if we don't have the infromation about the item purchased. Therefore, we'll try to use the neural network model to predict the categories that the customers will buy (using 4 targets), only based on the following features: age, gender, purchased amount in USD and location.
# In addition, we'll increase the number of epochs to let the model learn from the data.

# %%
# Create a dataframe with the columns that we'll use to predict tha customer characteristics and preferences
customer_df_2 = df[['age', 'gender', 'category', 'Purchase Amount (USD)', 'location']].copy()
customer_df_2.head()
# Out:
#    age gender  category  Purchase Amount (USD)       location
# 0   55   Male  Clothing                   53.0       Kentucky
# 1   19   Male  Clothing                   64.0          Maine
# 2   50   Male  Clothing                   73.0  Massachusetts
# 3   21   Male  Footwear                   90.0   Rhode Island
# 4   45   Male  Clothing                   49.0         Oregon

# %%
# Convert the categorical data in dummies and create a dataframe with that information
customer_df_encoded_2 = pd.get_dummies(customer_df_2)
customer_df_encoded_2.head()
# Out:
#    age  Purchase Amount (USD)  gender_Female  gender_Male  \
# 0   55                   53.0          False         True
# 1   19                   64.0          False         True
# 2   50                   73.0          False         True
# 3   21                   90.0          False         True
# 4   45                   49.0          False         True
#
#    category_Accessories  category_Clothing  category_Footwear  \
# 0                 False               True              False
# 1                 False               True              False
# 2                 False               True              False
# 3                 False              False               True
# 4                 False               True              False
#
#    category_Outerwear  location_Alabama  location_Alaska  ...  \
# 0               False             False            False  ...
# 1               False             False            False  ...
# 2               False             False            False  ...
# 3               False             False            False  ...
# 4               False             False            False  ...
#
#    location_South Dakota  location_Tennessee  location_Texas  location_Utah  \
# 0                  False               False           False          False
# 1                  False               False           False          False
# 2                  False               False           False          False
# 3                  False               False           False          False
# 4                  False               False           False          False
#
#    location_Vermont  location_Virginia  location_Washington  \
# 0             False              False                False
# 1             False              False                False
# 2             False              False                False
# 3             False              False                False
# 4             False              False                False
#
#    location_West Virginia  location_Wisconsin  location_Wyoming
# 0                   False               False             False
# 1                   False               False             False
# 2                   False               False             False
# 3                   False               False             False
# 4                   False               False             False
#
# [5 rows x 58 columns]

# %%
# Display the columns of the dataframe
customer_df_encoded_2.columns
# Out:
# Index(['age', 'Purchase Amount (USD)', 'gender_Female', 'gender_Male',
#        'category_Accessories', 'category_Clothing', 'category_Footwear',
#        'category_Outerwear', 'location_Alabama', 'location_Alaska',
#        'location_Arizona', 'location_Arkansas', 'location_California',
#        'location_Colorado', 'location_Connecticut', 'location_Delaware',
#        'location_Florida', 'location_Georgia', 'location_Hawaii',
#        'location_Idaho', 'location_Illinois', 'location_Indiana',
#        'location_Iowa', 'location_Kansas', 'location_Kentucky',
#        'location_Louisiana', 'location_Maine', 'location_Maryland',
#        'location_Massachusetts', 'location_Michigan', 'location_Minnesota',
#        'location_Mississippi', 'location_Missouri', 'location_Montana',
#        'location_Nebraska', 'location_Nevada', 'location_New Hampshire',
#        'location_New Jersey', 'location_New Mexico', 'location_New York',
#        'location_North Carolina', 'location_North Dakota', 'location_Ohio',
#        'location_Oklahoma', 'location_Oregon', 'location_Pennsylvania',
#        'location_Rhode Island', 'location_South Carolina',
#        'location_South Dakota', 'location_Tennessee', 'location_Texas',
#        'location_Utah', 'location_Vermont', 'location_Virginia',
#        'location_Washington', 'location_West Virginia', 'location_Wisconsin',
#        'location_Wyoming'],
#       dtype='object')

# %%
# Split our preprocessed data into our features and target arrays
#Features
X_3 = customer_df_encoded_2.drop(columns=['category_Accessories','category_Footwear','category_Clothing','category_Outerwear'],axis=1).values

#Targets
y_accessories_3 = customer_df_encoded_2['category_Accessories'].values
y_footwear_3 = customer_df_encoded_2['category_Footwear'].values
y_clothing_3 = customer_df_encoded_2['category_Clothing'].values
y_outerwear_3 = customer_df_encoded_2['category_Outerwear'].values

# Number of classes for each target variable
num_classes_accessories_3 = len(np.unique(y_accessories_3))
num_classes_footwear_3 = len(np.unique(y_footwear_3))
num_classes_clothing_3 = len(np.unique(y_clothing_3))
num_classes_outerwear_3 = len(np.unique(y_outerwear_3))

# Convert targets to one-hot encoding
y_accessories_3 = to_categorical(y_accessories_3, num_classes=num_classes_accessories_3).astype(np.float32)
y_footwear_3 = to_categorical(y_footwear_3, num_classes=num_classes_footwear_3).astype(np.float32)
y_clothing_3 = to_categorical(y_clothing_3, num_classes=num_classes_clothing_3).astype(np.float32)
y_outerwear_3 = to_categorical(y_outerwear_3, num_classes=num_classes_outerwear_3).astype(np.float32)

# Split the data into training and testing sets
X_train_3, X_test_3, y_accessories_train_3, y_accessories_test_3 = train_test_split(
    X, y_accessories_3, test_size=0.2, random_state=42
)

# Repeat the split for other targets, ensuring consistent splitting
y_footwear_train_3, y_footwear_test_3 = train_test_split(
    y_footwear_3, test_size=0.2, random_state=42
)
y_clothing_train_3, y_clothing_test_3 = train_test_split(
    y_clothing_3, test_size=0.2, random_state=42
)
y_outerwear_train_3, y_outerwear_test_3 = train_test_split(
    y_outerwear_3, test_size=0.2, random_state=42
)

# Define the model
X_train_3 = np.asarray(X_train_3).astype(np.float32)
X_test_3 = np.asarray(X_test_3).astype(np.float32)
inputs_3 = Input(shape=(X.shape[1],))

# Shared layers
x_3 = Dense(64, activation='relu')(inputs_3)
x_3 = Dense(32, activation='relu')(x_3)

# Output layers for each target
output_accessories_3 = Dense(num_classes_accessories_3, activation='softmax', name='accessories')(x_3)
output_footwear_3 = Dense(num_classes_footwear_3, activation='softmax', name='footwear')(x_3)
output_clothing_3 = Dense(num_classes_clothing_3, activation='softmax', name='clothing')(x_3)
output_outerwear_3 = Dense(num_classes_outerwear_3, activation='softmax', name='outerwear')(x_3)

# %%
# Define the model
X_train_3 = np.asarray(X_train_3).astype(np.float32)
X_test_3 = np.asarray(X_test_3).astype(np.float32)
inputs_3 = Input(shape=(X.shape[1],))

# Shared layers
x_3 = Dense(64, activation='relu')(inputs_3)
x_3 = Dense(32, activation='relu')(x_3)

# Output layers for each target
output_accessories_3 = Dense(num_classes_accessories_3, activation='softmax', name='accessories')(x_3)
output_footwear_3 = Dense(num_classes_footwear_3, activation='softmax', name='footwear')(x_3)
output_clothing_3 = Dense(num_classes_clothing_3, activation='softmax', name='clothing')(x_3)
output_outerwear_3 = Dense(num_classes_outerwear_3, activation='softmax', name='outerwear')(x_3)

# Create and compile the model
model_3 = Model(inputs=inputs_3, outputs=[output_accessories_3, output_footwear_3, output_clothing_3, output_outerwear_3])

model_3.compile(optimizer=Adam(),
              loss={'accessories': 'categorical_crossentropy',
                    'footwear': 'categorical_crossentropy',
                    'clothing': 'categorical_crossentropy',
                    'outerwear': 'categorical_crossentropy'},
              metrics={'accessories': 'accuracy',
                       'footwear': 'accuracy',
                       'clothing': 'accuracy',
                       'outerwear': 'accuracy'})

# Train the model
model_3.fit(X_train_3, {'accessories': y_accessories_train_3, 
                    'footwear': y_footwear_train_3, 
                    'clothing': y_clothing_train_3, 
                    'outerwear': y_outerwear_train_3},
          epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accessories_accuracy: 0.6077 - clothing_accuracy: 0.5693 - footwear_accuracy: 0.7405 - loss: 5.4245 - outerwear_accuracy: 0.6689
# Epoch 2/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6654 - clothing_accuracy: 0.5910 - footwear_accuracy: 0.8461 - loss: 2.0722 - outerwear_accuracy: 0.9133
# Epoch 3/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6682 - clothing_accuracy: 0.5882 - footwear_accuracy: 0.8572 - loss: 2.0147 - outerwear_accuracy: 0.9085
# Epoch 4/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accessories_accuracy: 0.6771 - clothing_accuracy: 0.6050 - footwear_accuracy: 0.8565 - loss: 1.9606 - outerwear_accuracy: 0.9234
# Epoch 5/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6725 - clothing_accuracy: 0.6145 - footwear_accuracy: 0.8578 - loss: 1.9715 - outerwear_accuracy: 0.9147
# Epoch 6/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accessories_accuracy: 0.6773 - clothing_accuracy: 0.6388 - footwear_accuracy: 0.8495 - loss: 1.9880 - outerwear_accuracy: 0.9017
# Epoch 7/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accessories_accuracy: 0.6826 - clothing_accuracy: 0.6294 - footwear_accuracy: 0.8448 - loss: 1.9885 - outerwear_accuracy: 0.9077
# Epoch 8/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6993 - clothing_accuracy: 0.6272 - footwear_accuracy: 0.8516 - loss: 1.9457 - outerwear_accuracy: 0.9074
# Epoch 9/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6925 - clothing_accuracy: 0.6216 - footwear_accuracy: 0.8430 - loss: 1.9481 - outerwear_accuracy: 0.9158
# Epoch 10/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6856 - clothing_accuracy: 0.6119 - footwear_accuracy: 0.8440 - loss: 1.9868 - outerwear_accuracy: 0.9083
# Epoch 11/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6821 - clothing_accuracy: 0.6259 - footwear_accuracy: 0.8518 - loss: 1.9484 - outerwear_accuracy: 0.9131
# Epoch 12/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7076 - clothing_accuracy: 0.6437 - footwear_accuracy: 0.8605 - loss: 1.8933 - outerwear_accuracy: 0.9131
# Epoch 13/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6999 - clothing_accuracy: 0.6463 - footwear_accuracy: 0.8492 - loss: 1.9162 - outerwear_accuracy: 0.9108
# Epoch 14/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7040 - clothing_accuracy: 0.6403 - footwear_accuracy: 0.8490 - loss: 1.9027 - outerwear_accuracy: 0.9235
# Epoch 15/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6849 - clothing_accuracy: 0.6195 - footwear_accuracy: 0.8477 - loss: 1.9435 - outerwear_accuracy: 0.9186
# Epoch 16/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6927 - clothing_accuracy: 0.6181 - footwear_accuracy: 0.8394 - loss: 1.9576 - outerwear_accuracy: 0.9122
# Epoch 17/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7009 - clothing_accuracy: 0.6489 - footwear_accuracy: 0.8464 - loss: 1.8993 - outerwear_accuracy: 0.9164
# Epoch 18/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7052 - clothing_accuracy: 0.6388 - footwear_accuracy: 0.8476 - loss: 1.9097 - outerwear_accuracy: 0.9211
# Epoch 19/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7027 - clothing_accuracy: 0.6391 - footwear_accuracy: 0.8495 - loss: 1.8843 - outerwear_accuracy: 0.9215
# Epoch 20/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7069 - clothing_accuracy: 0.6341 - footwear_accuracy: 0.8404 - loss: 1.9404 - outerwear_accuracy: 0.9177
# Epoch 21/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6949 - clothing_accuracy: 0.6308 - footwear_accuracy: 0.8457 - loss: 1.9356 - outerwear_accuracy: 0.9156
# Epoch 22/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6982 - clothing_accuracy: 0.6419 - footwear_accuracy: 0.8472 - loss: 1.9093 - outerwear_accuracy: 0.9062
# Epoch 23/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6931 - clothing_accuracy: 0.6573 - footwear_accuracy: 0.8565 - loss: 1.8797 - outerwear_accuracy: 0.9132
# Epoch 24/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6934 - clothing_accuracy: 0.6515 - footwear_accuracy: 0.8483 - loss: 1.9265 - outerwear_accuracy: 0.9154
# Epoch 25/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6913 - clothing_accuracy: 0.6599 - footwear_accuracy: 0.8396 - loss: 1.9033 - outerwear_accuracy: 0.9133
# Epoch 26/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accessories_accuracy: 0.7077 - clothing_accuracy: 0.6264 - footwear_accuracy: 0.8465 - loss: 1.9291 - outerwear_accuracy: 0.9134
# Epoch 27/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7151 - clothing_accuracy: 0.6539 - footwear_accuracy: 0.8486 - loss: 1.8819 - outerwear_accuracy: 0.9194
# Epoch 28/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7218 - clothing_accuracy: 0.6427 - footwear_accuracy: 0.8462 - loss: 1.8886 - outerwear_accuracy: 0.9153
# Epoch 29/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7285 - clothing_accuracy: 0.6209 - footwear_accuracy: 0.8471 - loss: 1.8985 - outerwear_accuracy: 0.9134
# Epoch 30/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7102 - clothing_accuracy: 0.6397 - footwear_accuracy: 0.8366 - loss: 1.9182 - outerwear_accuracy: 0.9119
# Epoch 31/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7186 - clothing_accuracy: 0.6411 - footwear_accuracy: 0.8456 - loss: 1.8879 - outerwear_accuracy: 0.9106
# Epoch 32/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7139 - clothing_accuracy: 0.6257 - footwear_accuracy: 0.8475 - loss: 1.9063 - outerwear_accuracy: 0.9123
# Epoch 33/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7270 - clothing_accuracy: 0.6489 - footwear_accuracy: 0.8439 - loss: 1.8494 - outerwear_accuracy: 0.9230
# Epoch 34/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7276 - clothing_accuracy: 0.6352 - footwear_accuracy: 0.8507 - loss: 1.8867 - outerwear_accuracy: 0.9087
# Epoch 35/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7264 - clothing_accuracy: 0.6509 - footwear_accuracy: 0.8521 - loss: 1.8303 - outerwear_accuracy: 0.9148
# Epoch 36/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7438 - clothing_accuracy: 0.6288 - footwear_accuracy: 0.8510 - loss: 1.8407 - outerwear_accuracy: 0.9156
# Epoch 37/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7447 - clothing_accuracy: 0.6364 - footwear_accuracy: 0.8458 - loss: 1.8352 - outerwear_accuracy: 0.9155
# Epoch 38/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7505 - clothing_accuracy: 0.6242 - footwear_accuracy: 0.8533 - loss: 1.8162 - outerwear_accuracy: 0.9179
# Epoch 39/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accessories_accuracy: 0.7375 - clothing_accuracy: 0.6310 - footwear_accuracy: 0.8601 - loss: 1.8163 - outerwear_accuracy: 0.9111
# Epoch 40/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accessories_accuracy: 0.7404 - clothing_accuracy: 0.6504 - footwear_accuracy: 0.8419 - loss: 1.7872 - outerwear_accuracy: 0.9211
# Epoch 41/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7422 - clothing_accuracy: 0.6444 - footwear_accuracy: 0.8497 - loss: 1.8060 - outerwear_accuracy: 0.9082
# Epoch 42/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7559 - clothing_accuracy: 0.6499 - footwear_accuracy: 0.8428 - loss: 1.7789 - outerwear_accuracy: 0.9135
# Epoch 43/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7527 - clothing_accuracy: 0.6539 - footwear_accuracy: 0.8493 - loss: 1.7502 - outerwear_accuracy: 0.9175
# Epoch 44/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7586 - clothing_accuracy: 0.6276 - footwear_accuracy: 0.8515 - loss: 1.7512 - outerwear_accuracy: 0.9131
# Epoch 45/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7516 - clothing_accuracy: 0.6556 - footwear_accuracy: 0.8404 - loss: 1.7366 - outerwear_accuracy: 0.9179
# Epoch 46/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7601 - clothing_accuracy: 0.6502 - footwear_accuracy: 0.8594 - loss: 1.7335 - outerwear_accuracy: 0.9113
# Epoch 47/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7598 - clothing_accuracy: 0.6506 - footwear_accuracy: 0.8385 - loss: 1.7081 - outerwear_accuracy: 0.9218
# Epoch 48/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7790 - clothing_accuracy: 0.6314 - footwear_accuracy: 0.8422 - loss: 1.7025 - outerwear_accuracy: 0.9197
# Epoch 49/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7678 - clothing_accuracy: 0.6294 - footwear_accuracy: 0.8359 - loss: 1.7303 - outerwear_accuracy: 0.9139
# Epoch 50/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7487 - clothing_accuracy: 0.6479 - footwear_accuracy: 0.8381 - loss: 1.7523 - outerwear_accuracy: 0.9108
# Epoch 51/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7615 - clothing_accuracy: 0.6473 - footwear_accuracy: 0.8517 - loss: 1.6969 - outerwear_accuracy: 0.9147
# Epoch 52/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7702 - clothing_accuracy: 0.6391 - footwear_accuracy: 0.8474 - loss: 1.6845 - outerwear_accuracy: 0.9213
# Epoch 53/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7629 - clothing_accuracy: 0.6615 - footwear_accuracy: 0.8561 - loss: 1.6620 - outerwear_accuracy: 0.9217
# Epoch 54/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7645 - clothing_accuracy: 0.6501 - footwear_accuracy: 0.8462 - loss: 1.6815 - outerwear_accuracy: 0.9225
# Epoch 55/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7737 - clothing_accuracy: 0.6685 - footwear_accuracy: 0.8562 - loss: 1.6525 - outerwear_accuracy: 0.9183
# Epoch 56/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7597 - clothing_accuracy: 0.6551 - footwear_accuracy: 0.8463 - loss: 1.6727 - outerwear_accuracy: 0.9211
# Epoch 57/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7684 - clothing_accuracy: 0.6676 - footwear_accuracy: 0.8570 - loss: 1.6507 - outerwear_accuracy: 0.9194
# Epoch 58/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7635 - clothing_accuracy: 0.6627 - footwear_accuracy: 0.8444 - loss: 1.6922 - outerwear_accuracy: 0.9185
# Epoch 59/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7748 - clothing_accuracy: 0.6666 - footwear_accuracy: 0.8551 - loss: 1.6408 - outerwear_accuracy: 0.9127
# Epoch 60/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7787 - clothing_accuracy: 0.6661 - footwear_accuracy: 0.8566 - loss: 1.6344 - outerwear_accuracy: 0.9138
# Epoch 61/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7734 - clothing_accuracy: 0.6792 - footwear_accuracy: 0.8554 - loss: 1.6390 - outerwear_accuracy: 0.9107
# Epoch 62/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7687 - clothing_accuracy: 0.6737 - footwear_accuracy: 0.8577 - loss: 1.6669 - outerwear_accuracy: 0.9074
# Epoch 63/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7697 - clothing_accuracy: 0.6679 - footwear_accuracy: 0.8701 - loss: 1.6365 - outerwear_accuracy: 0.9173
# Epoch 64/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7937 - clothing_accuracy: 0.6654 - footwear_accuracy: 0.8506 - loss: 1.6254 - outerwear_accuracy: 0.9118
# Epoch 65/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accessories_accuracy: 0.7807 - clothing_accuracy: 0.6826 - footwear_accuracy: 0.8522 - loss: 1.6094 - outerwear_accuracy: 0.9177
# Epoch 66/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7803 - clothing_accuracy: 0.6730 - footwear_accuracy: 0.8563 - loss: 1.6125 - outerwear_accuracy: 0.9105
# Epoch 67/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7715 - clothing_accuracy: 0.6561 - footwear_accuracy: 0.8557 - loss: 1.6199 - outerwear_accuracy: 0.9273
# Epoch 68/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7796 - clothing_accuracy: 0.6733 - footwear_accuracy: 0.8455 - loss: 1.6020 - outerwear_accuracy: 0.9284
# Epoch 69/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7726 - clothing_accuracy: 0.6851 - footwear_accuracy: 0.8624 - loss: 1.5761 - outerwear_accuracy: 0.9208
# Epoch 70/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7896 - clothing_accuracy: 0.6722 - footwear_accuracy: 0.8508 - loss: 1.5967 - outerwear_accuracy: 0.9231
# Epoch 71/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7850 - clothing_accuracy: 0.6762 - footwear_accuracy: 0.8563 - loss: 1.6036 - outerwear_accuracy: 0.9183
# Epoch 72/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7700 - clothing_accuracy: 0.6765 - footwear_accuracy: 0.8580 - loss: 1.6013 - outerwear_accuracy: 0.9231
# Epoch 73/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7950 - clothing_accuracy: 0.6923 - footwear_accuracy: 0.8615 - loss: 1.5550 - outerwear_accuracy: 0.9147
# Epoch 74/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7828 - clothing_accuracy: 0.7051 - footwear_accuracy: 0.8659 - loss: 1.5664 - outerwear_accuracy: 0.9172
# Epoch 75/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7863 - clothing_accuracy: 0.6999 - footwear_accuracy: 0.8641 - loss: 1.5597 - outerwear_accuracy: 0.9167
# Epoch 76/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7939 - clothing_accuracy: 0.6862 - footwear_accuracy: 0.8646 - loss: 1.5610 - outerwear_accuracy: 0.9183
# Epoch 77/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7889 - clothing_accuracy: 0.7004 - footwear_accuracy: 0.8620 - loss: 1.5471 - outerwear_accuracy: 0.9184
# Epoch 78/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accessories_accuracy: 0.7930 - clothing_accuracy: 0.6891 - footwear_accuracy: 0.8672 - loss: 1.5425 - outerwear_accuracy: 0.9215
# Epoch 79/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7882 - clothing_accuracy: 0.7113 - footwear_accuracy: 0.8684 - loss: 1.5337 - outerwear_accuracy: 0.9257
# Epoch 80/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7795 - clothing_accuracy: 0.6780 - footwear_accuracy: 0.8583 - loss: 1.5851 - outerwear_accuracy: 0.9187
# Epoch 81/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7753 - clothing_accuracy: 0.6897 - footwear_accuracy: 0.8583 - loss: 1.5747 - outerwear_accuracy: 0.9166
# Epoch 82/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7821 - clothing_accuracy: 0.7021 - footwear_accuracy: 0.8665 - loss: 1.5211 - outerwear_accuracy: 0.9208
# Epoch 83/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.8121 - clothing_accuracy: 0.6966 - footwear_accuracy: 0.8689 - loss: 1.5004 - outerwear_accuracy: 0.9185
# Epoch 84/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7940 - clothing_accuracy: 0.6840 - footwear_accuracy: 0.8669 - loss: 1.5353 - outerwear_accuracy: 0.9224
# Epoch 85/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7968 - clothing_accuracy: 0.6966 - footwear_accuracy: 0.8652 - loss: 1.5052 - outerwear_accuracy: 0.9288
# Epoch 86/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7901 - clothing_accuracy: 0.6959 - footwear_accuracy: 0.8740 - loss: 1.4962 - outerwear_accuracy: 0.9291
# Epoch 87/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.8054 - clothing_accuracy: 0.7099 - footwear_accuracy: 0.8754 - loss: 1.4822 - outerwear_accuracy: 0.9242
# Epoch 88/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7818 - clothing_accuracy: 0.7013 - footwear_accuracy: 0.8698 - loss: 1.5461 - outerwear_accuracy: 0.9191
# Epoch 89/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7931 - clothing_accuracy: 0.7073 - footwear_accuracy: 0.8761 - loss: 1.4810 - outerwear_accuracy: 0.9202
# Epoch 90/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7871 - clothing_accuracy: 0.6986 - footwear_accuracy: 0.8720 - loss: 1.5153 - outerwear_accuracy: 0.9132
# Epoch 91/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.8060 - clothing_accuracy: 0.6818 - footwear_accuracy: 0.8721 - loss: 1.5140 - outerwear_accuracy: 0.9208
# Epoch 92/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.8120 - clothing_accuracy: 0.6974 - footwear_accuracy: 0.8755 - loss: 1.4608 - outerwear_accuracy: 0.9224
# Epoch 93/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7994 - clothing_accuracy: 0.6846 - footwear_accuracy: 0.8675 - loss: 1.5309 - outerwear_accuracy: 0.9142
# Epoch 94/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7999 - clothing_accuracy: 0.6914 - footwear_accuracy: 0.8774 - loss: 1.4666 - outerwear_accuracy: 0.9268
# Epoch 95/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.8009 - clothing_accuracy: 0.6808 - footwear_accuracy: 0.8721 - loss: 1.5268 - outerwear_accuracy: 0.9230
# Epoch 96/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.8046 - clothing_accuracy: 0.6998 - footwear_accuracy: 0.8638 - loss: 1.4726 - outerwear_accuracy: 0.9301
# Epoch 97/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.8064 - clothing_accuracy: 0.6879 - footwear_accuracy: 0.8737 - loss: 1.4806 - outerwear_accuracy: 0.9147
# Epoch 98/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7991 - clothing_accuracy: 0.6836 - footwear_accuracy: 0.8785 - loss: 1.4771 - outerwear_accuracy: 0.9211
# Epoch 99/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7994 - clothing_accuracy: 0.7194 - footwear_accuracy: 0.8820 - loss: 1.4323 - outerwear_accuracy: 0.9329
# Epoch 100/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.8028 - clothing_accuracy: 0.7038 - footwear_accuracy: 0.8767 - loss: 1.4384 - outerwear_accuracy: 0.9274

# %%
# Evaluate the model
results_3 = model_3.evaluate(X_test_3, {'accessories': y_accessories_test_3, 
                                  'footwear': y_footwear_test_3, 
                                  'clothing': y_clothing_test_3, 
                                  'outerwear': y_outerwear_test_3})
# Print all results
for name, result in zip(model_3.metrics_names, results_3):
    print(f"{name}: {result}")
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.8038 - clothing_accuracy: 0.6563 - footwear_accuracy: 0.8892 - loss: 1.4697 - outerwear_accuracy: 0.9277
# loss: 1.4678400754928589
# compile_metrics: 0.8192307949066162

# %% [markdown]
# As we thought, predicting the category that the customer will but without the information about the item purchased gave us a lower accuracy, but still above 75%.
#
# We'll also try to increase this accuracy by including other valuable features that could give us a better idea of the customer's profile, such as: Subscription Status, Previous Purchases and Frequency of Purchases.

# %%
# Create a dataframe with the columns that we'll use to predict tha customer characteristics and preferences
customer_df_3 = df[['age', 'gender', 'category', 'Purchase Amount (USD)', 'location','Subscription Status','Previous Purchases','Frequency of Purchases']].copy()
customer_df_3.head()
# Out:
#    age gender  category  Purchase Amount (USD)       location  \
# 0   55   Male  Clothing                   53.0       Kentucky
# 1   19   Male  Clothing                   64.0          Maine
# 2   50   Male  Clothing                   73.0  Massachusetts
# 3   21   Male  Footwear                   90.0   Rhode Island
# 4   45   Male  Clothing                   49.0         Oregon
#
#   Subscription Status  Previous Purchases Frequency of Purchases
# 0                 Yes                  14            Fortnightly
# 1                 Yes                   2            Fortnightly
# 2                 Yes                  23                 Weekly
# 3                 Yes                  49                 Weekly
# 4                 Yes                  31               Annually

# %%
# Convert the categorical data in dummies and create a dataframe with that information
customer_df_encoded_3 = pd.get_dummies(customer_df_3)
customer_df_encoded_3.head()
# Out:
#    age  Purchase Amount (USD)  Previous Purchases  gender_Female  gender_Male  \
# 0   55                   53.0                  14          False         True
# 1   19                   64.0                   2          False         True
# 2   50                   73.0                  23          False         True
# 3   21                   90.0                  49          False         True
# 4   45                   49.0                  31          False         True
#
#    category_Accessories  category_Clothing  category_Footwear  \
# 0                 False               True              False
# 1                 False               True              False
# 2                 False               True              False
# 3                 False              False               True
# 4                 False               True              False
#
#    category_Outerwear  location_Alabama  ...  location_Wyoming  \
# 0               False             False  ...             False
# 1               False             False  ...             False
# 2               False             False  ...             False
# 3               False             False  ...             False
# 4               False             False  ...             False
#
#    Subscription Status_No  Subscription Status_Yes  \
# 0                   False                     True
# 1                   False                     True
# 2                   False                     True
# 3                   False                     True
# 4                   False                     True
#
#    Frequency of Purchases_Annually  Frequency of Purchases_Bi-Weekly  \
# 0                            False                             False
# 1                            False                             False
# 2                            False                             False
# 3                            False                             False
# 4                             True                             False
#
#    Frequency of Purchases_Every 3 Months  Frequency of Purchases_Fortnightly  \
# 0                                  False                                True
# 1                                  False                                True
# 2                                  False                               False
# 3                                  False                               False
# 4                                  False                               False
#
#    Frequency of Purchases_Monthly  Frequency of Purchases_Quarterly  \
# 0                           False                             False
# 1                           False                             False
# 2                           False                             False
# 3                           False                             False
# 4                           False                             False
#
#    Frequency of Purchases_Weekly
# 0                          False
# 1                          False
# 2                           True
# 3                           True
# 4                          False
#
# [5 rows x 68 columns]

# %%
# Display the columns of the dataframe
customer_df_encoded_3.columns
# Out:
# Index(['age', 'Purchase Amount (USD)', 'Previous Purchases', 'gender_Female',
#        'gender_Male', 'category_Accessories', 'category_Clothing',
#        'category_Footwear', 'category_Outerwear', 'location_Alabama',
#        'location_Alaska', 'location_Arizona', 'location_Arkansas',
#        'location_California', 'location_Colorado', 'location_Connecticut',
#        'location_Delaware', 'location_Florida', 'location_Georgia',
#        'location_Hawaii', 'location_Idaho', 'location_Illinois',
#        'location_Indiana', 'location_Iowa', 'location_Kansas',
#        'location_Kentucky', 'location_Louisiana', 'location_Maine',
#        'location_Maryland', 'location_Massachusetts', 'location_Michigan',
#        'location_Minnesota', 'location_Mississippi', 'location_Missouri',
#        'location_Montana', 'location_Nebraska', 'location_Nevada',
#        'location_New Hampshire', 'location_New Jersey', 'location_New Mexico',
#        'location_New York', 'location_North Carolina', 'location_North Dakota',
#        'location_Ohio', 'location_Oklahoma', 'location_Oregon',
#        'location_Pennsylvania', 'location_Rhode Island',
#        'location_South Carolina', 'location_South Dakota',
#        'location_Tennessee', 'location_Texas', 'location_Utah',
#        'location_Vermont', 'location_Virginia', 'location_Washington',
#        'location_West Virginia', 'location_Wisconsin', 'location_Wyoming',
#        'Subscription Status_No', 'Subscription Status_Yes',
#        'Frequency of Purchases_Annually', 'Frequency of Purchases_Bi-Weekly',
#        'Frequency of Purchases_Every 3 Months',
#        'Frequency of Purchases_Fortnightly', 'Frequency of Purchases_Monthly',
#        'Frequency of Purchases_Quarterly', 'Frequency of Purchases_Weekly'],
#       dtype='object')

# %%
# Split our preprocessed data into our features and target arrays
#Features
X_4 = customer_df_encoded_3.drop(columns=['category_Accessories','category_Footwear','category_Clothing','category_Outerwear'],axis=1).values

#Targets
y_accessories_4 = customer_df_encoded_3['category_Accessories'].values
y_footwear_4 = customer_df_encoded_3['category_Footwear'].values
y_clothing_4 = customer_df_encoded_3['category_Clothing'].values
y_outerwear_4 = customer_df_encoded_3['category_Outerwear'].values

# Number of classes for each target variable
num_classes_accessories_4 = len(np.unique(y_accessories_4))
num_classes_footwear_4 = len(np.unique(y_footwear_4))
num_classes_clothing_4 = len(np.unique(y_clothing_4))
num_classes_outerwear_4 = len(np.unique(y_outerwear_4))

# Convert targets to one-hot encoding
y_accessories_4 = to_categorical(y_accessories_4, num_classes=num_classes_accessories_4).astype(np.float32)
y_footwear_4 = to_categorical(y_footwear_4, num_classes=num_classes_footwear_4).astype(np.float32)
y_clothing_4 = to_categorical(y_clothing_4, num_classes=num_classes_clothing_4).astype(np.float32)
y_outerwear_4 = to_categorical(y_outerwear_4, num_classes=num_classes_outerwear_4).astype(np.float32)

# Split the data into training and testing sets
X_train_4, X_test_4, y_accessories_train_4, y_accessories_test_4 = train_test_split(
    X, y_accessories_4, test_size=0.2, random_state=42
)

# Repeat the split for other targets, ensuring consistent splitting
y_footwear_train_4, y_footwear_test_4 = train_test_split(
    y_footwear_4, test_size=0.2, random_state=42
)
y_clothing_train_4, y_clothing_test_4 = train_test_split(
    y_clothing_4, test_size=0.2, random_state=42
)
y_outerwear_train_4, y_outerwear_test_4 = train_test_split(
    y_outerwear_4, test_size=0.2, random_state=42
)

# Define the model
X_train_4 = np.asarray(X_train_4).astype(np.float32)
X_test_4 = np.asarray(X_test_4).astype(np.float32)
inputs_4 = Input(shape=(X.shape[1],))

# Shared layers
x_4 = Dense(64, activation='relu')(inputs_4)
x_4 = Dense(32, activation='relu')(x_4)

# Output layers for each target
output_accessories_4 = Dense(num_classes_accessories_4, activation='softmax', name='accessories')(x_4)
output_footwear_4 = Dense(num_classes_footwear_4, activation='softmax', name='footwear')(x_4)
output_clothing_4 = Dense(num_classes_clothing_4, activation='softmax', name='clothing')(x_4)
output_outerwear_4 = Dense(num_classes_outerwear_4, activation='softmax', name='outerwear')(x_4)

# %%
# Define the model
X_train_4 = np.asarray(X_train_4).astype(np.float32)
X_test_4 = np.asarray(X_test_4).astype(np.float32)
inputs_4 = Input(shape=(X.shape[1],))

# Shared layers
x_4 = Dense(64, activation='relu')(inputs_4)
x_4 = Dense(32, activation='relu')(x_4)

# Output layers for each target
output_accessories_4 = Dense(num_classes_accessories_4, activation='softmax', name='accessories')(x_4)
output_footwear_4 = Dense(num_classes_footwear_4, activation='softmax', name='footwear')(x_4)
output_clothing_4 = Dense(num_classes_clothing_4, activation='softmax', name='clothing')(x_4)
output_outerwear_4 = Dense(num_classes_outerwear_4, activation='softmax', name='outerwear')(x_4)

# Create and compile the model
model_4 = Model(inputs=inputs_4, outputs=[output_accessories_4, output_footwear_4, output_clothing_4, output_outerwear_4])

model_4.compile(optimizer=Adam(),
              loss={'accessories': 'categorical_crossentropy',
                    'footwear': 'categorical_crossentropy',
                    'clothing': 'categorical_crossentropy',
                    'outerwear': 'categorical_crossentropy'},
              metrics={'accessories': 'accuracy',
                       'footwear': 'accuracy',
                       'clothing': 'accuracy',
                       'outerwear': 'accuracy'})

# Train the model
model_4.fit(X_train_4, {'accessories': y_accessories_train_4, 
                    'footwear': y_footwear_train_4, 
                    'clothing': y_clothing_train_4, 
                    'outerwear': y_outerwear_train_4},
          epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accessories_accuracy: 0.5753 - clothing_accuracy: 0.5548 - footwear_accuracy: 0.8230 - loss: 5.8530 - outerwear_accuracy: 0.8825
# Epoch 2/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6659 - clothing_accuracy: 0.6202 - footwear_accuracy: 0.8587 - loss: 2.0326 - outerwear_accuracy: 0.9067
# Epoch 3/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6859 - clothing_accuracy: 0.6052 - footwear_accuracy: 0.8544 - loss: 2.0158 - outerwear_accuracy: 0.9160
# Epoch 4/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6716 - clothing_accuracy: 0.6042 - footwear_accuracy: 0.8319 - loss: 2.0209 - outerwear_accuracy: 0.9188
# Epoch 5/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6627 - clothing_accuracy: 0.6156 - footwear_accuracy: 0.8553 - loss: 1.9734 - outerwear_accuracy: 0.9280
# Epoch 6/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6685 - clothing_accuracy: 0.6046 - footwear_accuracy: 0.8501 - loss: 2.0380 - outerwear_accuracy: 0.9064
# Epoch 7/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6870 - clothing_accuracy: 0.6062 - footwear_accuracy: 0.8494 - loss: 1.9949 - outerwear_accuracy: 0.9103
# Epoch 8/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6921 - clothing_accuracy: 0.6216 - footwear_accuracy: 0.8511 - loss: 1.9893 - outerwear_accuracy: 0.9151
# Epoch 9/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6886 - clothing_accuracy: 0.6199 - footwear_accuracy: 0.8517 - loss: 1.9647 - outerwear_accuracy: 0.9159
# Epoch 10/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6568 - clothing_accuracy: 0.6273 - footwear_accuracy: 0.8507 - loss: 2.0021 - outerwear_accuracy: 0.9065
# Epoch 11/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6992 - clothing_accuracy: 0.6227 - footwear_accuracy: 0.8516 - loss: 1.9454 - outerwear_accuracy: 0.9154
# Epoch 12/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6761 - clothing_accuracy: 0.6076 - footwear_accuracy: 0.8416 - loss: 1.9877 - outerwear_accuracy: 0.9200
# Epoch 13/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accessories_accuracy: 0.6769 - clothing_accuracy: 0.6014 - footwear_accuracy: 0.8441 - loss: 1.9979 - outerwear_accuracy: 0.9207
# Epoch 14/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accessories_accuracy: 0.6659 - clothing_accuracy: 0.6349 - footwear_accuracy: 0.8533 - loss: 1.9227 - outerwear_accuracy: 0.9163
# Epoch 15/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accessories_accuracy: 0.6940 - clothing_accuracy: 0.6177 - footwear_accuracy: 0.8536 - loss: 1.9335 - outerwear_accuracy: 0.9205
# Epoch 16/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6721 - clothing_accuracy: 0.6170 - footwear_accuracy: 0.8466 - loss: 1.9392 - outerwear_accuracy: 0.9242
# Epoch 17/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6879 - clothing_accuracy: 0.6117 - footwear_accuracy: 0.8527 - loss: 1.9468 - outerwear_accuracy: 0.9143
# Epoch 18/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6861 - clothing_accuracy: 0.6254 - footwear_accuracy: 0.8409 - loss: 1.9518 - outerwear_accuracy: 0.9148
# Epoch 19/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6887 - clothing_accuracy: 0.6383 - footwear_accuracy: 0.8566 - loss: 1.8933 - outerwear_accuracy: 0.9205
# Epoch 20/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6784 - clothing_accuracy: 0.6367 - footwear_accuracy: 0.8473 - loss: 1.9476 - outerwear_accuracy: 0.9066
# Epoch 21/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6915 - clothing_accuracy: 0.6103 - footwear_accuracy: 0.8336 - loss: 2.0086 - outerwear_accuracy: 0.9095
# Epoch 22/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6959 - clothing_accuracy: 0.6371 - footwear_accuracy: 0.8385 - loss: 1.9420 - outerwear_accuracy: 0.9134
# Epoch 23/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6790 - clothing_accuracy: 0.6345 - footwear_accuracy: 0.8540 - loss: 1.9159 - outerwear_accuracy: 0.9138
# Epoch 24/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6940 - clothing_accuracy: 0.6242 - footwear_accuracy: 0.8496 - loss: 1.9098 - outerwear_accuracy: 0.9193
# Epoch 25/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7051 - clothing_accuracy: 0.6254 - footwear_accuracy: 0.8233 - loss: 1.9537 - outerwear_accuracy: 0.9232
# Epoch 26/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6948 - clothing_accuracy: 0.6267 - footwear_accuracy: 0.8483 - loss: 1.9184 - outerwear_accuracy: 0.9110
# Epoch 27/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7087 - clothing_accuracy: 0.6331 - footwear_accuracy: 0.8478 - loss: 1.9033 - outerwear_accuracy: 0.9154
# Epoch 28/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6688 - clothing_accuracy: 0.6462 - footwear_accuracy: 0.8486 - loss: 1.9155 - outerwear_accuracy: 0.9142
# Epoch 29/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.6914 - clothing_accuracy: 0.6333 - footwear_accuracy: 0.8327 - loss: 1.9063 - outerwear_accuracy: 0.9185
# Epoch 30/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7335 - clothing_accuracy: 0.6397 - footwear_accuracy: 0.8495 - loss: 1.8484 - outerwear_accuracy: 0.9174
# Epoch 31/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7135 - clothing_accuracy: 0.6412 - footwear_accuracy: 0.8509 - loss: 1.8925 - outerwear_accuracy: 0.9100
# Epoch 32/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7317 - clothing_accuracy: 0.6475 - footwear_accuracy: 0.8448 - loss: 1.8416 - outerwear_accuracy: 0.9157
# Epoch 33/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7119 - clothing_accuracy: 0.6287 - footwear_accuracy: 0.8396 - loss: 1.8672 - outerwear_accuracy: 0.9203
# Epoch 34/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7384 - clothing_accuracy: 0.6421 - footwear_accuracy: 0.8393 - loss: 1.8326 - outerwear_accuracy: 0.9170
# Epoch 35/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7224 - clothing_accuracy: 0.6536 - footwear_accuracy: 0.8527 - loss: 1.8344 - outerwear_accuracy: 0.9069
# Epoch 36/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7333 - clothing_accuracy: 0.6349 - footwear_accuracy: 0.8506 - loss: 1.8357 - outerwear_accuracy: 0.9175
# Epoch 37/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7444 - clothing_accuracy: 0.6284 - footwear_accuracy: 0.8393 - loss: 1.8337 - outerwear_accuracy: 0.9201
# Epoch 38/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7360 - clothing_accuracy: 0.6248 - footwear_accuracy: 0.8437 - loss: 1.8706 - outerwear_accuracy: 0.9155
# Epoch 39/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7434 - clothing_accuracy: 0.6347 - footwear_accuracy: 0.8495 - loss: 1.8164 - outerwear_accuracy: 0.9227
# Epoch 40/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7324 - clothing_accuracy: 0.6486 - footwear_accuracy: 0.8482 - loss: 1.8030 - outerwear_accuracy: 0.9226
# Epoch 41/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7513 - clothing_accuracy: 0.6397 - footwear_accuracy: 0.8499 - loss: 1.8078 - outerwear_accuracy: 0.9129
# Epoch 42/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7557 - clothing_accuracy: 0.6430 - footwear_accuracy: 0.8545 - loss: 1.7529 - outerwear_accuracy: 0.9254
# Epoch 43/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7561 - clothing_accuracy: 0.6400 - footwear_accuracy: 0.8549 - loss: 1.8070 - outerwear_accuracy: 0.9051
# Epoch 44/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7398 - clothing_accuracy: 0.6408 - footwear_accuracy: 0.8545 - loss: 1.7850 - outerwear_accuracy: 0.9139
# Epoch 45/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7577 - clothing_accuracy: 0.6446 - footwear_accuracy: 0.8489 - loss: 1.7705 - outerwear_accuracy: 0.9184
# Epoch 46/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7337 - clothing_accuracy: 0.6270 - footwear_accuracy: 0.8457 - loss: 1.8112 - outerwear_accuracy: 0.9151
# Epoch 47/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accessories_accuracy: 0.7528 - clothing_accuracy: 0.6319 - footwear_accuracy: 0.8462 - loss: 1.7928 - outerwear_accuracy: 0.9125
# Epoch 48/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7467 - clothing_accuracy: 0.6350 - footwear_accuracy: 0.8592 - loss: 1.7688 - outerwear_accuracy: 0.9127
# Epoch 49/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7444 - clothing_accuracy: 0.6494 - footwear_accuracy: 0.8623 - loss: 1.7492 - outerwear_accuracy: 0.9135
# Epoch 50/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accessories_accuracy: 0.7580 - clothing_accuracy: 0.6369 - footwear_accuracy: 0.8474 - loss: 1.7760 - outerwear_accuracy: 0.9093
# Epoch 51/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7533 - clothing_accuracy: 0.6551 - footwear_accuracy: 0.8564 - loss: 1.7377 - outerwear_accuracy: 0.9173
# Epoch 52/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7583 - clothing_accuracy: 0.6418 - footwear_accuracy: 0.8473 - loss: 1.7744 - outerwear_accuracy: 0.9110
# Epoch 53/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7434 - clothing_accuracy: 0.6543 - footwear_accuracy: 0.8528 - loss: 1.7479 - outerwear_accuracy: 0.9139
# Epoch 54/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7612 - clothing_accuracy: 0.6477 - footwear_accuracy: 0.8472 - loss: 1.7622 - outerwear_accuracy: 0.9118
# Epoch 55/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7405 - clothing_accuracy: 0.6418 - footwear_accuracy: 0.8549 - loss: 1.7624 - outerwear_accuracy: 0.9183
# Epoch 56/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7601 - clothing_accuracy: 0.6425 - footwear_accuracy: 0.8421 - loss: 1.7456 - outerwear_accuracy: 0.9199
# Epoch 57/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7566 - clothing_accuracy: 0.6341 - footwear_accuracy: 0.8512 - loss: 1.7426 - outerwear_accuracy: 0.9169
# Epoch 58/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7373 - clothing_accuracy: 0.6378 - footwear_accuracy: 0.8481 - loss: 1.7747 - outerwear_accuracy: 0.9202
# Epoch 59/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7531 - clothing_accuracy: 0.6559 - footwear_accuracy: 0.8523 - loss: 1.7321 - outerwear_accuracy: 0.9104
# Epoch 60/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7669 - clothing_accuracy: 0.6506 - footwear_accuracy: 0.8542 - loss: 1.7050 - outerwear_accuracy: 0.9195
# Epoch 61/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7458 - clothing_accuracy: 0.6464 - footwear_accuracy: 0.8459 - loss: 1.7780 - outerwear_accuracy: 0.9121
# Epoch 62/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7551 - clothing_accuracy: 0.6460 - footwear_accuracy: 0.8522 - loss: 1.7290 - outerwear_accuracy: 0.9156
# Epoch 63/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7688 - clothing_accuracy: 0.6436 - footwear_accuracy: 0.8551 - loss: 1.7192 - outerwear_accuracy: 0.9110
# Epoch 64/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7680 - clothing_accuracy: 0.6617 - footwear_accuracy: 0.8509 - loss: 1.7005 - outerwear_accuracy: 0.9161
# Epoch 65/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7643 - clothing_accuracy: 0.6511 - footwear_accuracy: 0.8470 - loss: 1.7145 - outerwear_accuracy: 0.9132
# Epoch 66/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7635 - clothing_accuracy: 0.6495 - footwear_accuracy: 0.8522 - loss: 1.7027 - outerwear_accuracy: 0.9150
# Epoch 67/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7793 - clothing_accuracy: 0.6422 - footwear_accuracy: 0.8325 - loss: 1.7378 - outerwear_accuracy: 0.9112
# Epoch 68/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7625 - clothing_accuracy: 0.6512 - footwear_accuracy: 0.8496 - loss: 1.7182 - outerwear_accuracy: 0.9085
# Epoch 69/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7588 - clothing_accuracy: 0.6562 - footwear_accuracy: 0.8462 - loss: 1.6977 - outerwear_accuracy: 0.9172
# Epoch 70/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7576 - clothing_accuracy: 0.6393 - footwear_accuracy: 0.8398 - loss: 1.7318 - outerwear_accuracy: 0.9127
# Epoch 71/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7615 - clothing_accuracy: 0.6728 - footwear_accuracy: 0.8515 - loss: 1.6953 - outerwear_accuracy: 0.9187
# Epoch 72/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7662 - clothing_accuracy: 0.6628 - footwear_accuracy: 0.8525 - loss: 1.6735 - outerwear_accuracy: 0.9219
# Epoch 73/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7781 - clothing_accuracy: 0.6548 - footwear_accuracy: 0.8358 - loss: 1.6841 - outerwear_accuracy: 0.9191
# Epoch 74/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7634 - clothing_accuracy: 0.6478 - footwear_accuracy: 0.8530 - loss: 1.6622 - outerwear_accuracy: 0.9205
# Epoch 75/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accessories_accuracy: 0.7591 - clothing_accuracy: 0.6667 - footwear_accuracy: 0.8585 - loss: 1.6949 - outerwear_accuracy: 0.9140
# Epoch 76/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7672 - clothing_accuracy: 0.6421 - footwear_accuracy: 0.8551 - loss: 1.6799 - outerwear_accuracy: 0.9200
# Epoch 77/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7738 - clothing_accuracy: 0.6701 - footwear_accuracy: 0.8373 - loss: 1.6866 - outerwear_accuracy: 0.9100
# Epoch 78/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7823 - clothing_accuracy: 0.6650 - footwear_accuracy: 0.8427 - loss: 1.6604 - outerwear_accuracy: 0.9169
# Epoch 79/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7715 - clothing_accuracy: 0.6582 - footwear_accuracy: 0.8526 - loss: 1.6683 - outerwear_accuracy: 0.9169
# Epoch 80/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7766 - clothing_accuracy: 0.6568 - footwear_accuracy: 0.8373 - loss: 1.6870 - outerwear_accuracy: 0.9135
# Epoch 81/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7851 - clothing_accuracy: 0.6612 - footwear_accuracy: 0.8476 - loss: 1.6333 - outerwear_accuracy: 0.9239
# Epoch 82/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7909 - clothing_accuracy: 0.6521 - footwear_accuracy: 0.8472 - loss: 1.6577 - outerwear_accuracy: 0.9126
# Epoch 83/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7904 - clothing_accuracy: 0.6604 - footwear_accuracy: 0.8537 - loss: 1.6552 - outerwear_accuracy: 0.9135
# Epoch 84/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7896 - clothing_accuracy: 0.6515 - footwear_accuracy: 0.8612 - loss: 1.6321 - outerwear_accuracy: 0.9148
# Epoch 85/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7899 - clothing_accuracy: 0.6509 - footwear_accuracy: 0.8432 - loss: 1.6471 - outerwear_accuracy: 0.9204
# Epoch 86/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7837 - clothing_accuracy: 0.6602 - footwear_accuracy: 0.8550 - loss: 1.6535 - outerwear_accuracy: 0.9172
# Epoch 87/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7849 - clothing_accuracy: 0.6716 - footwear_accuracy: 0.8441 - loss: 1.6549 - outerwear_accuracy: 0.9165
# Epoch 88/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7789 - clothing_accuracy: 0.6661 - footwear_accuracy: 0.8475 - loss: 1.6408 - outerwear_accuracy: 0.9134
# Epoch 89/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7928 - clothing_accuracy: 0.6661 - footwear_accuracy: 0.8470 - loss: 1.6388 - outerwear_accuracy: 0.9163
# Epoch 90/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7723 - clothing_accuracy: 0.6688 - footwear_accuracy: 0.8522 - loss: 1.6409 - outerwear_accuracy: 0.9198
# Epoch 91/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7949 - clothing_accuracy: 0.6587 - footwear_accuracy: 0.8401 - loss: 1.6216 - outerwear_accuracy: 0.9222
# Epoch 92/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7942 - clothing_accuracy: 0.6612 - footwear_accuracy: 0.8416 - loss: 1.6412 - outerwear_accuracy: 0.9205
# Epoch 93/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7957 - clothing_accuracy: 0.6563 - footwear_accuracy: 0.8356 - loss: 1.6304 - outerwear_accuracy: 0.9105
# Epoch 94/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7935 - clothing_accuracy: 0.6634 - footwear_accuracy: 0.8591 - loss: 1.5968 - outerwear_accuracy: 0.9179
# Epoch 95/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7922 - clothing_accuracy: 0.6593 - footwear_accuracy: 0.8408 - loss: 1.6295 - outerwear_accuracy: 0.9183
# Epoch 96/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7849 - clothing_accuracy: 0.6668 - footwear_accuracy: 0.8448 - loss: 1.6269 - outerwear_accuracy: 0.9066
# Epoch 97/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7924 - clothing_accuracy: 0.6585 - footwear_accuracy: 0.8429 - loss: 1.6250 - outerwear_accuracy: 0.9203
# Epoch 98/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7838 - clothing_accuracy: 0.6573 - footwear_accuracy: 0.8491 - loss: 1.6410 - outerwear_accuracy: 0.9088
# Epoch 99/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7965 - clothing_accuracy: 0.6681 - footwear_accuracy: 0.8495 - loss: 1.6093 - outerwear_accuracy: 0.9148
# Epoch 100/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.7875 - clothing_accuracy: 0.6551 - footwear_accuracy: 0.8342 - loss: 1.6695 - outerwear_accuracy: 0.9149

# %%
# Evaluate the model
results_4 = model_4.evaluate(X_test_4, {'accessories': y_accessories_test_4, 
                                  'footwear': y_footwear_test_4, 
                                  'clothing': y_clothing_test_4, 
                                  'outerwear': y_outerwear_test_4})
# Print all results
for name, result in zip(model_4.metrics_names, results_4):
    print(f"{name}: {result}")
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accessories_accuracy: 0.8053 - clothing_accuracy: 0.6234 - footwear_accuracy: 0.8612 - loss: 1.6550 - outerwear_accuracy: 0.9211
# loss: 1.6478596925735474
# compile_metrics: 0.8038461804389954

# %% [markdown]
# By increasing the features we didn't notice a major improvement in accuracy (and for some categories it was lower). Probably, the additional features included did not provide any value for predicting the categories.

# %% [markdown]
# Instead of the categories, we now want to focus on the items purchased. We will try using a neural network model to predict an specific item purchased by a customer (in this case Jewelry), in which the category is not a feature.

# %%
# Create a dataframe with the columns that we'll use to predict tha customer characteristics and preferences
customer_df_4 = df[['age', 'gender', 'Item Purchased', 'Purchase Amount (USD)', 'location','Subscription Status','Previous Purchases','Frequency of Purchases']].copy()
customer_df_4.head()
# Out:
#    age gender Item Purchased  Purchase Amount (USD)       location  \
# 0   55   Male         Blouse                   53.0       Kentucky
# 1   19   Male        Sweater                   64.0          Maine
# 2   50   Male          Jeans                   73.0  Massachusetts
# 3   21   Male        Sandals                   90.0   Rhode Island
# 4   45   Male         Blouse                   49.0         Oregon
#
#   Subscription Status  Previous Purchases Frequency of Purchases
# 0                 Yes                  14            Fortnightly
# 1                 Yes                   2            Fortnightly
# 2                 Yes                  23                 Weekly
# 3                 Yes                  49                 Weekly
# 4                 Yes                  31               Annually

# %%
# Convert the categorical data in dummies and create a dataframe with that information
customer_df_encoded_4 = pd.get_dummies(customer_df_4)
customer_df_encoded_4.head()
# Out:
#    age  Purchase Amount (USD)  Previous Purchases  gender_Female  gender_Male  \
# 0   55                   53.0                  14          False         True
# 1   19                   64.0                   2          False         True
# 2   50                   73.0                  23          False         True
# 3   21                   90.0                  49          False         True
# 4   45                   49.0                  31          False         True
#
#    Item Purchased_Backpack  Item Purchased_Belt  Item Purchased_Blouse  \
# 0                    False                False                   True
# 1                    False                False                  False
# 2                    False                False                  False
# 3                    False                False                  False
# 4                    False                False                   True
#
#    Item Purchased_Boots  Item Purchased_Coat  ...  location_Wyoming  \
# 0                 False                False  ...             False
# 1                 False                False  ...             False
# 2                 False                False  ...             False
# 3                 False                False  ...             False
# 4                 False                False  ...             False
#
#    Subscription Status_No  Subscription Status_Yes  \
# 0                   False                     True
# 1                   False                     True
# 2                   False                     True
# 3                   False                     True
# 4                   False                     True
#
#    Frequency of Purchases_Annually  Frequency of Purchases_Bi-Weekly  \
# 0                            False                             False
# 1                            False                             False
# 2                            False                             False
# 3                            False                             False
# 4                             True                             False
#
#    Frequency of Purchases_Every 3 Months  Frequency of Purchases_Fortnightly  \
# 0                                  False                                True
# 1                                  False                                True
# 2                                  False                               False
# 3                                  False                               False
# 4                                  False                               False
#
#    Frequency of Purchases_Monthly  Frequency of Purchases_Quarterly  \
# 0                           False                             False
# 1                           False                             False
# 2                           False                             False
# 3                           False                             False
# 4                           False                             False
#
#    Frequency of Purchases_Weekly
# 0                          False
# 1                          False
# 2                           True
# 3                           True
# 4                          False
#
# [5 rows x 89 columns]

# %%
# Display the columns of the dataframe
customer_df_encoded_4.columns
# Out:
# Index(['age', 'Purchase Amount (USD)', 'Previous Purchases', 'gender_Female',
#        'gender_Male', 'Item Purchased_Backpack', 'Item Purchased_Belt',
#        'Item Purchased_Blouse', 'Item Purchased_Boots', 'Item Purchased_Coat',
#        'Item Purchased_Dress', 'Item Purchased_Gloves',
#        'Item Purchased_Handbag', 'Item Purchased_Hat', 'Item Purchased_Hoodie',
#        'Item Purchased_Jacket', 'Item Purchased_Jeans',
#        'Item Purchased_Jewelry', 'Item Purchased_Pants',
#        'Item Purchased_Sandals', 'Item Purchased_Scarf',
#        'Item Purchased_Shirt', 'Item Purchased_Shoes', 'Item Purchased_Shorts',
#        'Item Purchased_Skirt', 'Item Purchased_Sneakers',
#        'Item Purchased_Socks', 'Item Purchased_Sunglasses',
#        'Item Purchased_Sweater', 'Item Purchased_T-shirt', 'location_Alabama',
#        'location_Alaska', 'location_Arizona', 'location_Arkansas',
#        'location_California', 'location_Colorado', 'location_Connecticut',
#        'location_Delaware', 'location_Florida', 'location_Georgia',
#        'location_Hawaii', 'location_Idaho', 'location_Illinois',
#        'location_Indiana', 'location_Iowa', 'location_Kansas',
#        'location_Kentucky', 'location_Louisiana', 'location_Maine',
#        'location_Maryland', 'location_Massachusetts', 'location_Michigan',
#        'location_Minnesota', 'location_Mississippi', 'location_Missouri',
#        'location_Montana', 'location_Nebraska', 'location_Nevada',
#        'location_New Hampshire', 'location_New Jersey', 'location_New Mexico',
#        'location_New York', 'location_North Carolina', 'location_North Dakota',
#        'location_Ohio', 'location_Oklahoma', 'location_Oregon',
#        'location_Pennsylvania', 'location_Rhode Island',
#        'location_South Carolina', 'location_South Dakota',
#        'location_Tennessee', 'location_Texas', 'location_Utah',
#        'location_Vermont', 'location_Virginia', 'location_Washington',
#        'location_West Virginia', 'location_Wisconsin', 'location_Wyoming',
#        'Subscription Status_No', 'Subscription Status_Yes',
#        'Frequency of Purchases_Annually', 'Frequency of Purchases_Bi-Weekly',
#        'Frequency of Purchases_Every 3 Months',
#        'Frequency of Purchases_Fortnightly', 'Frequency of Purchases_Monthly',
#        'Frequency of Purchases_Quarterly', 'Frequency of Purchases_Weekly'],
#       dtype='object')

# %%
# Split our preprocessed data into our features and target arrays
X_5 = customer_df_encoded_4.drop('Item Purchased_Jewelry', axis=1).values
y_5 = customer_df_encoded_4['Item Purchased_Jewelry'].values

# Split the preprocessed data into a training and testing dataset
X_train_5, X_test_5, y_train_5, y_test_5 = train_test_split(X_5, y_5, random_state = 78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler_5 = scaler.fit(X_train_5)

# Scale the data
X_train_scaled_5 = X_scaler_5.transform(X_train_5)
X_test_scaled_5 = X_scaler_5.transform(X_test_5)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_5[0])
hidden_nodes_layer1 =  8
hidden_nodes_layer2 = 5

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# c:\Users\danie\anaconda3\envs\dev2\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_19 (Dense)                │ (None, 8)              │           712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 5)              │            45 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 763 (2.98 KB)
#  Trainable params: 763 (2.98 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled_5,y_train_5,epochs=10)
# Out:
# Epoch 1/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8099 - loss: 0.5806
# Epoch 2/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9468 - loss: 0.3521
# Epoch 3/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - accuracy: 0.9523 - loss: 0.2232
# Epoch 4/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step - accuracy: 0.9547 - loss: 0.1779
# Epoch 5/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9607 - loss: 0.1369
# Epoch 6/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - accuracy: 0.9598 - loss: 0.1176
# Epoch 7/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9559 - loss: 0.1079
# Epoch 8/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - accuracy: 0.9539 - loss: 0.0905
# Epoch 9/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step - accuracy: 0.9581 - loss: 0.0709
# Epoch 10/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - accuracy: 0.9680 - loss: 0.0541

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled_5,y_test_5,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 31/31 - 0s - 4ms/step - accuracy: 0.9713 - loss: 0.0530
# Loss: 0.05295950546860695, Accuracy: 0.9712820649147034

# %% [markdown]
# With the selected features it is possible to predict the selected Jewelry item. This could be due to the fact that we have the purchase amount as a feature (higher purchase amounts in general are associated to Jewelry). However, it is important to highlight that we are limitting the number of epochs to 10 because we want to avoid the overfitting observed in previous models due to the available data.

# %% [markdown]
# We'll also try to apply the same model, but without considering the purchase amount as feature, so it does not bias the result due to the price difference observed in different products (ex. Jewelry is usually more expensive than jeans).

# %%
# Create a dataframe with the columns that we'll use to predict tha customer characteristics and preferences
customer_df_5 = df[['age', 'gender', 'Item Purchased', 'location','Subscription Status','Previous Purchases','Frequency of Purchases']].copy()
customer_df_5.head()
# Out:
#    age gender Item Purchased       location Subscription Status  \
# 0   55   Male         Blouse       Kentucky                 Yes
# 1   19   Male        Sweater          Maine                 Yes
# 2   50   Male          Jeans  Massachusetts                 Yes
# 3   21   Male        Sandals   Rhode Island                 Yes
# 4   45   Male         Blouse         Oregon                 Yes
#
#    Previous Purchases Frequency of Purchases
# 0                  14            Fortnightly
# 1                   2            Fortnightly
# 2                  23                 Weekly
# 3                  49                 Weekly
# 4                  31               Annually

# %%
# Convert the categorical data in dummies and create a dataframe with that information
customer_df_encoded_5 = pd.get_dummies(customer_df_5)
customer_df_encoded_5.head()
# Out:
#    age  Previous Purchases  gender_Female  gender_Male  \
# 0   55                  14          False         True
# 1   19                   2          False         True
# 2   50                  23          False         True
# 3   21                  49          False         True
# 4   45                  31          False         True
#
#    Item Purchased_Backpack  Item Purchased_Belt  Item Purchased_Blouse  \
# 0                    False                False                   True
# 1                    False                False                  False
# 2                    False                False                  False
# 3                    False                False                  False
# 4                    False                False                   True
#
#    Item Purchased_Boots  Item Purchased_Coat  Item Purchased_Dress  ...  \
# 0                 False                False                 False  ...
# 1                 False                False                 False  ...
# 2                 False                False                 False  ...
# 3                 False                False                 False  ...
# 4                 False                False                 False  ...
#
#    location_Wyoming  Subscription Status_No  Subscription Status_Yes  \
# 0             False                   False                     True
# 1             False                   False                     True
# 2             False                   False                     True
# 3             False                   False                     True
# 4             False                   False                     True
#
#    Frequency of Purchases_Annually  Frequency of Purchases_Bi-Weekly  \
# 0                            False                             False
# 1                            False                             False
# 2                            False                             False
# 3                            False                             False
# 4                             True                             False
#
#    Frequency of Purchases_Every 3 Months  Frequency of Purchases_Fortnightly  \
# 0                                  False                                True
# 1                                  False                                True
# 2                                  False                               False
# 3                                  False                               False
# 4                                  False                               False
#
#    Frequency of Purchases_Monthly  Frequency of Purchases_Quarterly  \
# 0                           False                             False
# 1                           False                             False
# 2                           False                             False
# 3                           False                             False
# 4                           False                             False
#
#    Frequency of Purchases_Weekly
# 0                          False
# 1                          False
# 2                           True
# 3                           True
# 4                          False
#
# [5 rows x 88 columns]

# %%
# Split our preprocessed data into our features and target arrays
X_6 = customer_df_encoded_5.drop('Item Purchased_Jewelry', axis=1).values
y_6 = customer_df_encoded_5['Item Purchased_Jewelry'].values

# Split the preprocessed data into a training and testing dataset
X_train_6, X_test_6, y_train_6, y_test_6 = train_test_split(X_6, y_6, random_state = 78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler_6 = scaler.fit(X_train_6)

# Scale the data
X_train_scaled_6 = X_scaler_6.transform(X_train_6)
X_test_scaled_6 = X_scaler_6.transform(X_test_6)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_6[0])
hidden_nodes_layer1 =  8
hidden_nodes_layer2 = 5

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# c:\Users\danie\anaconda3\envs\dev2\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_22 (Dense)                │ (None, 8)              │           704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 5)              │            45 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 755 (2.95 KB)
#  Trainable params: 755 (2.95 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled_6,y_train_6,epochs=10)
# Out:
# Epoch 1/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 1s 960us/step - accuracy: 0.5922 - loss: 0.6715
# Epoch 2/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9036 - loss: 0.3388
# Epoch 3/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9444 - loss: 0.2395
# Epoch 4/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9496 - loss: 0.1953
# Epoch 5/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step - accuracy: 0.9539 - loss: 0.1650
# Epoch 6/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9559 - loss: 0.1467
# Epoch 7/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step - accuracy: 0.9551 - loss: 0.1390
# Epoch 8/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - accuracy: 0.9557 - loss: 0.1244
# Epoch 9/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - accuracy: 0.9516 - loss: 0.1158
# Epoch 10/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9537 - loss: 0.1032

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled_6,y_test_6,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 31/31 - 0s - 4ms/step - accuracy: 0.9579 - loss: 0.1073
# Loss: 0.10732738673686981, Accuracy: 0.9579487442970276

# %% [markdown]
# Although the result is not materially different than from the previuos attempt, we think that this last model is more useful for predicting the item purchased given that we don't have to rely on the purchase amount, which could bias the result.
